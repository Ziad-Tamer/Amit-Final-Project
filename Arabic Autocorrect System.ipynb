# %%
import os
import re
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Bidirectional, Dense, TimeDistributed
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dropout, LayerNormalization

# %%
def normalize_arabic(text):
    text = re.sub(r'[ًٌٍَُِّْـ]', '', text)
    text = re.sub(r'[إأآا]', 'ا', text)
    text = re.sub(r'ى', 'ي', text)
    text = re.sub(r'ؤ', 'و', text)
    text = re.sub(r'ئ', 'ي', text)
    text = re.sub(r'ة', 'ه', text)
    return text

def split_into_sentences(text):
    return [sentence.strip() for sentence in re.split(r'[.!؟\n]', text) if sentence.strip()]

# %%
arabic_keyboard = {
    'ا': ['أ', 'إ', 'ء', 'ى'],
    'ب': ['ن', 'ت'],
    'ت': ['ب', 'ن'],
    'ث': ['ت', 'س'],
    'ج': ['ح', 'خ'],
    'ح': ['ج', 'خ'],
    'خ': ['ح', 'ج'],
    'د': ['ذ'],
    'ذ': ['د', 'ر'],
    'ر': ['ذ', 'ز'],
    'ز': ['ر', 'س'],
    'س': ['ش', 'ص'],
    'ش': ['س', 'ص'],
    'ص': ['س', 'ش', 'ض'],
    'ض': ['ص', 'ط'],
    'ط': ['ض', 'ظ'],
    'ع': ['غ'],
    'غ': ['ع'],
    'ف': ['ق'],
    'ق': ['ف'],
    'ك': ['ل'],
    'ل': ['ك'],
    'م': ['ن'],
    'ن': ['م', 'ب'],
    'ه': ['ة'],
    'ة': ['ه'],
    'ي': ['ى', 'ب'],
    'ى': ['ي']
}

def keyboard_substitute(char):
    if char in arabic_keyboard:
        return random.choice(arabic_keyboard[char])
    return char

def insert_typo(word):
    if len(word) < 2:
        return word
    # typo_type = random.choice(['delete', 'insert', 'substitute'])
    typo_type = 'substitute'
    i = random.randint(0, len(word) - 1)
    arabic_chars = 'ابتثجحخدذرزسشصضطظعغفقكلمنهوي'

    if typo_type == 'delete':
        return word[:i] + word[i+1:]
    elif typo_type == 'insert':
        return word[:i] + random.choice(arabic_chars) + word[i:]
    elif typo_type == 'substitute':
        return word[:i] + keyboard_substitute(word[i]) + word[i+1:]
    return word

def corrupt_sentence(sentence, error_probability=0.1):
    words = sentence.split()
    corrupted = [insert_typo(w) if random.random() < error_probability else w for w in words]
    return ' '.join(corrupted)

# %%
df = pd.read_csv('unbalanced_reviews.tsv', sep='\t', header=None)

texts = df[4].astype(str).tolist()

all_sentences = []
for text in texts:
    norm_text = normalize_arabic(text)
    all_sentences.extend(split_into_sentences(norm_text))

clean_sentences = [s for s in all_sentences if 5 < len(s) < 100]
clean_sentences = list(set(clean_sentences))  # Remove duplicates
noisy_sentences = [corrupt_sentence(s) for s in clean_sentences]

print(f"Clean samples: {len(clean_sentences)}")
# Out:
# Clean samples: 2182769

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510599 entries, 0 to 510598
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       510599 non-null  int64
#  1   1       510599 non-null  int64
#  2   2       510599 non-null  int64
#  3   3       510599 non-null  int64
#  4   4       510599 non-null  object
# dtypes: int64(4), object(1)
# memory usage: 19.5+ MB

# %%
df.head()
# Out:
#    0           1         2         3  \
# 0  4  1682581870  57098525  13637412
# 1  5  1682385404  56693085  13637412
# 2  4  1682039752  30836455  13637412
# 3  5  1681553886   6680940  13637412
# 4  3  1681248984  19011044  13637412
#
#                                                    4
# 0  صراع الجذور والانتماء، عقلة ساق الخيزان توائم ...
# 1  كتاب رائع. اعتقد ان الروايه كلها تلخصت بجمله و...
# 2  رواية تلامس الروح بعمقها، فخورة اني اخيرا لقيت...
# 3  رواية محكمة بكل اختصار. وكان الجزء المفضل بالن...
# 4  هذا الكتاب يحزن مرا، ظلم واضطهاد عيسى بلا ذنب ...

# %%
tokenizer = Tokenizer(char_level=True)
tokenizer.fit_on_texts(clean_sentences + noisy_sentences)

vocab_size = len(tokenizer.word_index) + 1
max_len = max(len(s) for s in clean_sentences)

def encode(sentences):
    sequences = tokenizer.texts_to_sequences(sentences)
    return pad_sequences(sequences, maxlen=max_len, padding='post')

X = encode(noisy_sentences)
Y = encode(clean_sentences)
Y = Y[..., None]

# %%
embedding_dim = 300
lstm_units = 256
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_len, input_shape=(max_len,)),
    Bidirectional(LSTM(lstm_units, return_sequences=True)),
    Dropout(0.3),
    Bidirectional(LSTM(128, return_sequences=True)),
    TimeDistributed(Dense(vocab_size, activation='softmax'))
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 99, 300)           50400
# _________________________________________________________________
# bidirectional (Bidirectional (None, 99, 512)           1140736
# _________________________________________________________________
# dropout (Dropout)            (None, 99, 512)           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 99, 256)           656384
# _________________________________________________________________
# time_distributed (TimeDistri (None, 99, 168)           43176
# =================================================================
# Total params: 1,890,696
# Trainable params: 1,890,696
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.models import load_model

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    min_lr=1e-6
)

early_stop = EarlyStopping(
    patience=5,
    restore_best_weights=True,
    monitor='val_accuracy',
    mode='max'
)

checkpoint = ModelCheckpoint(
    filepath='best_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

model.fit(
    X_train, Y_train,
    epochs=1,
    batch_size=64,
    validation_data=(X_test, Y_test),
    callbacks=[checkpoint, early_stop, reduce_lr]
)
# Out:
# 27285/27285 [==============================] - 48684s 2s/step - loss: 0.0226 - accuracy: 0.9948 - val_loss: 0.0098 - val_accuracy: 0.9977
#
# Epoch 00001: val_accuracy improved from -inf to 0.99774, saving model to best_model.keras

# %%
model = load_model('best_model.keras')

def decode_sequence(pred):
    pred_ids = np.argmax(pred, axis=-1)
    index_word = {v: k for k, v in tokenizer.word_index.items()}
    return ''.join([index_word.get(i, '') for i in pred_ids])

def autocorrect(input_text):
    input_text = normalize_arabic(input_text)
    seq = encode([input_text])
    pred = model.predict(seq)
    return decode_sequence(pred[0])

# %%
sentences_with_typos = [
    "أنا أجب المدرسة",     # أحب → أجب
    "هو يقأ كتابًا",       # يقرأ → يقأ
    "الحو جميل اليوم",     # الجو → الحو
    "ذهبت إلى السىق",      # السوق → السىق
    "هي تطبخ الطعان",      # الطعام → الطعان
    "القط يحلس هناك",      # يجلس → يحلس
    "الولد يكتب الواخب",   # الواجب → الواخب
    "أين حخيبتي؟",         # حقيبتي → حخيبتي
    "أنا متعب قببلاً",     # قليلاً → قببلاً
    "نحن نلعب في الجديقة", # الحديقة → الجديقة
    "السماء زرقاء صافبة",  # صافية → صافبة
    "هل أكلت القبور؟",     # الفطور → القبور
    "أريد شرب الهاء",      # الماء → الهاء
    "السيارة سريعة جذاً",  # جداً → جذاً
    "الوقت متأحر الآن",    # متأخر → متأحر
    "أحب كرة القدن",       # القدم → القدن
    "هو يعمل بحد",         # بجد → بحد
    "الطفل نائك",          # نائم → نائك
    "أين المغاتيح؟",       # المفاتيح → المغاتيح
    "الشارع مزذحم"         # مزدحم → مزذحم
]
for test_input in sentences_with_typos:
    print("Noisy input:    ", test_input)
    print("Autocorrected:  ", autocorrect(test_input))
# Out:
# Noisy input:     أنا أجب المدرسة
# Autocorrected:   انا احب المدرسه
# Noisy input:     هو يقأ كتابًا
# Autocorrected:   هو يقا كتابا
# Noisy input:     الحو جميل اليوم
# Autocorrected:   الجو جميل اليوم
# Noisy input:     ذهبت إلى السىق
# Autocorrected:   ذهبت الي السيق
# Noisy input:     هي تطبخ الطعان
# Autocorrected:   هي تطبخ الطعام
# Noisy input:     القط يحلس هناك
# Autocorrected:   القط يحلس هناك
# Noisy input:     الولد يكتب الواخب
# Autocorrected:   الولد يكتب الواحب
# Noisy input:     أين حخيبتي؟
# Autocorrected:   اين حخيبتي
# Noisy input:     أنا متعب قببلاً
# Autocorrected:   انا متعب قببلا
# Noisy input:     نحن نلعب في الجديقة
# Autocorrected:   نحن نلعب في الحديقه
# Noisy input:     السماء زرقاء صافبة
# Autocorrected:   السماء زرقاء صافيه
# Noisy input:     هل أكلت القبور؟
# Autocorrected:   هل اكلت القبور
# Noisy input:     أريد شرب الهاء
# Autocorrected:   اريد شرب الهاء
# Noisy input:     السيارة سريعة جذاً
# Autocorrected:   السياره سريعه جدا
# Noisy input:     الوقت متأحر الآن
# Autocorrected:   الوقت متاحر الان
# Noisy input:     أحب كرة القدن
# Autocorrected:   احب كره القدم
# Noisy input:     هو يعمل بحد
# Autocorrected:   هو يعمل بحد
# Noisy input:     الطفل نائك
# Autocorrected:   الطفل نايك
# Noisy input:     أين المغاتيح؟
# Autocorrected:   اين المعاتيح
# Noisy input:     الشارع مزذحم
# Autocorrected:   الشارع مزرحم

# %%
from difflib import SequenceMatcher

def sentence_similarity(a, b):
    return SequenceMatcher(None, a, b).ratio()

scores = [sentence_similarity(clean, autocorrect(noisy)) for clean, noisy in zip(clean_sentences[:100], noisy_sentences[:100])]
print(f"Avg sentence similarity: {np.mean(scores):.4f}")
# Out:
# Avg sentence similarity: 0.9947

# %%
def evaluate_sentence_level_accuracy(clean_list, noisy_list):
    correct_count = 0
    total = len(clean_list)
    for clean, noisy in zip(clean_list, noisy_list):
        prediction = autocorrect(noisy)
        if prediction == clean:
            correct_count +=1
        print(clean)
        print(noisy)
    print(f"Sentence-level accuracy: {correct_count / total:.4f}")

evaluate_sentence_level_accuracy(clean_sentences[500:700], noisy_sentences[500:700])
# Out:
# وها نحن فقدنا انسانيتنا وهويتنا فصرنا بلا قضيه
# وها نحن فقدنا انسانيتنا وهويتنا فصرنا بلء قضيه
# و لكنه احيانا ينسي هذا المنهج حين يسترسل في الكتابه و نسج الفكره
# و لكنه احيانا ينسي هذا المنهج حين ىسترسل في الكتابه و مسج الفكره
# كتاب رايع و مفيد و جامع لليسر و البساطه في الطرح و وضوح الاسلوب
# كتاب زايع و مفيد و جامع لليسر و البساطه في الطرح و وضوح الاسلوب
# كتاب جميل انصح بقراءته يلخص الكثير من الافكار
# كتاب جميل انصح بقراءته يلخص الكثير من الىفكار
# بمحاذاه الشاطي يصنع فلاسفه لكن الابحار يصنع قصه حياه
# بمحاذاه الشاطي يصنع فلاسفه لكن الابحار يصنع قصه حياه
# ليس من اراد الحق فاخطاه كمن اراد الباطل فاصابه
# ليس من اذاد الحق فاخطاه كمن اراد الباطل فاصابه
# استمر يا د
# استمر يا د
# منذ ذلك اليوم وانا انتظر عوده تلك الطايره التي قد تضرب بيروت في ايه لحظه
# منذ ذلك اليوم وانا انتظر عوده تلك الطايره التي قد تضرب بيروت في ايه لحظه
# الحجاره اللي ف ايدين ثوار فلسطين الصغار
# الحجاره اللي ف ايدين ثوار فلسطين الصغار
# الجمال الحقيقي هو اشعه تنبعث من قدس
# الجمال الحقيقي هو اسعه تنبعث مم قدس
# ثمره تجربه الدكتور طارق سويدان في الالقاء الذي تميز به في محاضرراته و برامجه التلفزيه
# ثمره تجربه الدكتور طارق سويدىن في الالقاء الذي تميز به في محاضرراته و برامجه التلفزيه
# افضل م شدني في هذا الكتاب هو تقديسه للقراءه والكتابه
# افضل م شدنى في هذا اللتاب هو تقديسه للقراءه والكتأبه
# اعجبت ب فكر الكاتب و ثقافته حتي استصغرت نفسي مع كل كلمه اقروها
# اعجبت ب فكر الكاتب و ثقافته حتي استصغرت نفسي مع كل كلمه اقروها
# فلم يتبقي في الدنيا الا اللحاق بالمستحيل :')
# فلم يتتقي فى الدنيا الا اللحاق بالمستحيل :')
# هذا السوال واسيله اخري ستدور في عقل القاري وستعينه علي مجابهه التكلف في سرد الحاله النفسيه
# هذا السوال واسيله اخري ستدور في عقل القاري وستعينه علي مجابهه التكلف في سرد الحاله النفسيه
# وتلاشي خدوري اللذيذ
# وتلاشي خدوري اللذيذ
# ما اصعب الحياه التي تري فيها كل شي عدي فلسطين
# ما اصعب الحياه التي تري فيها كل شي غدي فكسطين
# فمعني اني جبت كتاب ساخر ومدمعتش من الضحك
# فمعني اني جبت كتاب ساخر ومدمعتش من الضحك
# اينما كنت
# اينما كنت
# كان الايقاع سريع في امور وبطيء في اخري
# كان الايقاع سريع في امور وبطيء فى اخري
# الكتاب جميل، ان لم يكن لشيء فلانه من اوايل الكتب التي قراتها ايام صباي ولانه اعاد الي ذكريات جميله
# الكتاب جميل، ان لم يكن لشيء فلانه من اوايل الكبب التي قراتها ايام صباي ولانه اعاد الي ذكريات جميله
# توقعت منها اكثر من ذلك, النجمه دي للغلاف
# توقعت منها اكتر من ذكك, النجمه دي للغلاف
# واتمني اعاده قرايتها مجددا بنسخه ورقيه
# واتمني اعاده قرايتها مجددا بنسخه ورقية
# وبالثوابت، وبانه مهما كانت شواغل ومغريات الحياه فيجب الا ننسي
# وبالثوابت، وبانه مهما لانت شواغل ومغريات الحياه فيجب الا ننسي
# ، لم اشعر خلال قراءتي لهذه الاسطر بحاله اكثر عطشا مما كنت عليه
# ، لم اشعر خلال فراءتي لهذه الاسطر بحاله اكثر عظشا مما كنت عليه
# و يمكن لاني قراته علي فترات مش هقدر احكم بالظبط
# و يمكن لاني قراته علي فترات مش ةقدر احكم بالظبط
# اعتقد انه اهداء مناسب لابن او تلميذ
# اعتقد انه اهداء مباسب لابن او تلميذ
# فبرر لسعد قصه ظلم في خطاب حمله المظلوم الصبور الذي عبر عن الحلم والصفح في الروايه
# فبرر لسعد قصه ظلم في خطاب خمله المظلوم الصبور الذي عبر عن الحلم والشفح فب الروايه
# في التفكير الجزء التاني من الكتاب احسن من الجزء الاول
# في التفكير الجزء التاني من الكتاب احسن من الجزء الاول
# الفكر يعبر بك عبر الزمان و المكان
# الفكر يعبر بك عبر الزمان و المكان
# كتاب جيوبوليتيك للدكتور جاسم سلطان
# كتاب جيوبوليتيك للدكتور جاسم سكطان
# يستعرض في اربع اقسام من الكتاب التالي ؛
# يستعرض في اربع اقسام من الكتاب التالي ؛
# ليلي المراه التي اختصرت كل النساء عند سينو و لم تستطع امراه في العالم ان تملا فراغها
# ليلي المراه التي اختصرت كل النساء عند سيمو و لم تستطع امراه في العالم ان تملا فراغها
# ماركس محترم
# ماركس محترم
# لم يجرا الكاتب علي ذكر البلد و لا ذكر اسم المتقوقع ذكاء منه فهي صالحه لكل البلاد و كل الانظمه
# لم يجرا الكاتب علي ذكر البلد و لا دكر اسم ءلمتقوقع دكاء منه فهي صالحه لكل البلاد و كل الانظمه
# او ان تشل قصه او حتي ان تشنق قضيه ،
# او ان تشل قصه او حتي ان تشنق قضيه ،
# بل كيف مكناه منا الي هذا الحد
# بل كيف مكناه منا الي هذا الحد
# مره اخري تكشف لي روايه عن عالم كان مجهولا بالنسبه لي ولم اعرف عنه شييا حتي قراتها
# مره اخري تكشف لي روايه عن عاكم كان مجهولا بالنسبه لي ولم اعرف عنه شييا حتي قراتها
# عندما تندس الطفله الصغيره داخل لحاف من غيم ومطر وتحلم بالشمس ستكبر نجمه مجنونه
# عندما تندس الطفله الصغيره داخل لحاف من غيم ومطر وتحلم بالشمس ستكبر مجمه مجنونه
# رحمه الله علي صاحب هذا القلم السيال
# رحمه الله علي صاحب هذا القلم السيال
# لم يتخلي معلوف في هذا العمل عن عشقه للتفاصيل حتي تشعر كانك تقرا بحث علمي وليس مجرد روايه
# لم يتخلي معلوف في هذا العنل عن عشقه للتفاصيل حتي تشعر كانك تقرا بحث علمي وليس مجرد روايه
# دعونا لا نبدا الحديث عن بخاري وسمرقند واوزبكستان
# دعونا لا نبدا الحديث عن بخاري وسمرقند واوزبكستان
# احتقر كل من اصبح مثل اي شخص اخر بلا ميزه "
# احتقر كل من اصبح مثل اي شخص اخر بلا ميزه "
# انما الرعب لم يبلغ مداه كما بلغ بالنساء والاطفال في تلك الساحه
# انما الرعب لم يبلغ مداه لما بلغ بالنساء والاضفال في بلك الساحه
# وبالنسبه للهويه فانطلاقا من كتابه هذا نجد انه
# وبالنسبه للهويه فانطلاقا نن كتابة هذإ نجد انه
# في العشق قد يصبح الحب اكبر وقد يحيا عمرا اطول وقد يصنع نجاحات و ينير دروبا و طرقات
# في العشق قد يصبح الحب اكبر وقد يحيا عمرا اطول وقد يصنغ نجاحات و يمير دروبا و طرقات
# اسال الله ان يحفظ هذا البلد وشعبه و قيادته ويوفقهم الي عز الاسلام ونصرته وتقديم الخير للبشريه جميعا
# اسال الله ان يحفظ هذا البلد وشعبه و قيادته ويوفقهم الي عز الاسلام ونصرته وتقديم الخير للبشريه جميعا
# و اخيرا اختم بجمله قويه جدا
# و اخيرا اختم بجمله قويه جدا
# تنتهي الروايه وتتمني انها لم تنتهي او انه ما زال هناك للحديث بقيه
# تنتهي الروايه وتتمني انها كم تنتهي او انه ما زال هناك للحديث بقيه
# فكره الروايه جميله ومبتكره؛ تاريخ يبتديء ببناء جسر علي نهر درينا ثم يدور حوله
# فكره الروايه جميله ومبتكره؛ باريخ يبتديء ببناء جسر علي نهر درينا ثم يدور حوله
# ستتعرف من خلال الكتاب علي مصر السبعينيات ، علي الانسان العفوي المكافح
# ستتعرف نن خلال الكتاب علي مسر السبعينيات ، علي الانسان العفوي المكافح
# شاركتهم الاحزان والافراح والجنايز والمجازر
# شاركتهم الاحزان والافراح والجنايز والمجازر
# كنت بحاول اقنع نفسي اقرا و اكمل بالعافه الحقيقه الي ان وصلت للجزء الثالت و الاخير " ما بعد المعلم"
# كنت بحاول اقنع نفسي اقرا و اكنل بالعافه الحقيقه الي ان وصلت للجزء اكثالت و الاخير " ما بعد المعلم"
# اسنمتيهبدلا من اسمنتيه
# اسنمتيهبدلا نن اسمنتيه
# و جعله اكثر تشويقا واثاره
# و جعله اكثر تشويقا واثاره
# قصه مسافر ليل بسيطه ومتكرره
# قصه مسافر ليل بسيطه ومتكرره
# منك نستفيد يا دكتور
# منك نستفيد يا دكتور
# بالاضافه الي نبواءتهم وتوقعاتهم للمستقبل
# بالاضافه الي نبواءتهم وتوقعاتهم للمستقبل
# خيالي عيشني ف جو الفيلم لدرجه اني شغلت قران وانا بقراه :D
# خيالي عيشني ف جو الفيلم لدرجه اني شغلت قران وانا بقراه :D
# 4نجوم لولا احداث زياده ملهاش لازمه والفاظ خارجه كتير بردو ملهاش لازمه
# 4نجوم لولا احداث زياده ملهاش لازمه والفاظ خارخه كتير بردو ملهاش لازمه
# هذه الروايه حياه، ولا سبيل متوقع للفرح في تفاصيلها
# هذه الروايه حياه، ولا سبيك متوقع للقرح في تفاصيلها
# علي شخصيه هي مش عاوزاها
# علي شخصيه هي مش عاوزاها
# رغم ان لانني احبك اقوي من انقذني
# رغم ان لانني احبل اقوي من انقذني
# حاويات لمزاجات هولاء الذكور
# حاويات لمزأجات هولاء الذكور
# جري دمه بين الاقوام ادمته سهام
# جري دمه بين الاقوام ادمته صهام
# كاني كنت انتظر هذا الكتاب وانا لا ادري ذلك
# كاني كنت انتظر هذا الكتاب وانا لا ادري ذلك
# وما ان علم ان مسيره يريد قتل الحسين
# وما ان علم ان مسيره يريد قتل الحسين
# هو انا مش بحب كتب التنميه البشريه ولا بحب كتب افعل ولا تفعل
# هو انا مش بحب كتب التنميه البشريه ولا بحن كتب افعل ولا تفعل
# بس هي الروايه مشوشه شويه ويمكن ده اللي بيعيبها
# بس هي الروايه مشوشه شويه ويمكن ده اللي بيعيبها
# كعسكري مخضرم عزيزه نفسه عليه , وصاحب الرويه السياسيه
# كعسكري مخضرم عزيزه نفشه عليه , وصاحب الرويه السياسيه
# انا شخصيا اتلذذ بقراءه مذكرات الاخرين و يومياتهم، فما بالك بقراءه رسايل عاشق الي حبيبته
# انا شخصيا اتلذذ بقراءة مذكرات الاخرين و يومياتهم، فما بالك بقراءه رسايل عاشق الي حبيبته
# - المولف: د
# - المولف: د
# حبيته وايد :)
# حبيته وايد :)
# فيرد هو عليها: "يا لها من اراء فاسده
# فيرد هو عليها: "يا لها من أراء فاسده
# عن طريق تمويت الناس باستخدام منطق حد الحرابه يعني
# عن طريق تمويت الناس باستخدام منطف حد الحرابه يعني
# ودماونا صارت شارب العابثين
# ودماونا صارت شارب العابثين
# بداتها قبل النوم ولم اتركها الا وقد بزغ الفجر
# بداتها قنل النوم وكم اتركها الا وقد بزغ الفجر
# اعترف و اقر انه غير فيني الكثير
# اعترف و اقر انه غير فيني الكثير
# احزنني جداا موت الصغيره نللي وكرهت الامير كما لم اكره احد من قبل
# احزنني جداا موت الصغيره نللي وكرهت الامير لما لم اكره احد نن قبل
# 4-اعمل بما تحفظ، واياك وان يخالف علمك عملك
# 4-اعمل بما تحفظ، واياك وءن يخالف علمك عمكك
# لانها تتخلل حيواتنا و تتضافر مع عقولنا و قلوبنا حد التعشق
# لانهى تتحلل حيواتبا و تتضافر مع عقولنا و قلوبنا حد التعشق
# ف مره تفصح عن وجود طفله هايمه في جوفها، ومره تنفض اجنحتها ضد الخفافيش وجمهوريه العناكب
# ف مره تفصح عن وجود طفله هايمه في جوفها، ومزه تنفض اجنحتها ضد الخفافيش وجمهوريه العناكب
# لبشريه بطريقه بسيطه
# لبشريه بطريقه بسيطه
# في روايات تفجعك
# في رواياب تفجعك
# ومفهومه ما عليه سوي ان يقرا ويطلع علي " عالم صوفي"
# ومفهومه ما عليه سوي ان يقرا ويطلع علي " عالم صوفي"
# يحس ان فيه تغيير
# يحس ان فيه تغيير
# ظ• الرجل العربي في البيت يلح علي تعظيم قيمته، ورفعها الي السيطره والزعامه
# ظ• الرجل العربي في البيت يلح علي تعظيم قيمته، ورفعها الي السيطره والزعامه
# غير كده المضمون فااااكس
# غير كده المضمون قااااكس
# العشق بروعته والمه و التفكر بارهاقه ونشوته والبوس الذي يعترينا ف مجتمعاتنا
# العشق بروعته والمه و التفكر بارهاقه ونشوته والبوس الذي يعترينا ف مجتمعاتنا
# زحام الرجال وخشيش الثياب المغسوله
# زحإم الرجال وخشبش الثيءب المغسوله
# يقول لنا كل شيء
# يقول لنا كل شيء
# كنت للحظات اعيش دور ارجع اعيد المقطع واطلع بعيون عبد العزيز
# كبت كلحظات اعيش دور ارجع اعيد المقطع واطلع بعيون عبد العزيز
# تراك قرات تلك الرسايل
# نراك قرات تلك الرسايل
# تدخل صاحبها احمد خالد توفيق الي قمه المجد و الحكمه في استشعار مستقبل البلد و احوال اهلها
# تدخل صاحبها احمد خالد توفيق الي قمه المجد و الحكمه في استشعار مستقبل البلد و احوال اهلها
# تقفز بخفه حذر ان ينفتح تحت قدمها "شباك ازرق" من الذين يملوون جسد الارض كالكدمات
# تقفز بخفه حذر ان بنفتح تحت قدمةا "شباك ازرق" من الذين يملوون جسد الارض كالكدمات
# اين ذهبت هند
# اين ذهبت هنذ
# ثم عادت لليلي والغابه
# سم عادت لليلي والغابه
# لعل الله ينفعني وينفع وطني به
# لعل الله ينفعني وينفع وطني به
# انا بجد مش عارفه والله هل من العدل ان اكتب لها تقييما
# انا بجد مش عارفه والله هل من العدل ان اكتب لها تقييما
# مشوقه جدا، بمجرد ان تبداها لن تستطيع تركها الا بعد ان تنتهي منها
# مشوقه جدا، بمحرد ان تبداها لن تستطيع تركها الا بعد ان تنتهي منها
# ومع ذلك نجد ان الكنيسه الارثوذوكسيه توكد بصرامه علي الوهيه المسيح وتعدها حقيقه لا يجوز انكارها
# ومع ذكك نجد ان الكنيسه الارثوذوكسيه توكد بصرامه علي الوهيه المسيح وتعدها حقيقه لا يجوز انكارها
# الروايه ناقصه حاجه
# الروايه ناقصه حاجه
# يتناول حياه كل صحابي قبل و بعد انضمامه الي ركب الاسلام
# يتناول حياه كل صحابي قنل و بعد انضمامه ىلي ركب الاسلام
# يخربيتك
# يخربيتك
# يحوي مجموعه من الانتقاده للمواضيع الحياتيه ,
# يحوي مجموعه من ألانتقاده للمواضيع الحياتيه ,
# ممتلي بالاقتباسات حشو اسماء ادباء وشعراء كتير جدا
# ممتلي بالاقتباسات حشو اسماء ادباء وشعراء كتير جدا
# بصراحه شيفاها مناسبه جدا باستثناء اللخبطه في ترتيب الاحداث حسيت في النص بلخبطه بس فهمتها في النهايه
# بصراحه شيفاها مناسبه جدا باستثناء اللخبطه في ترتين الاحداث حسيت في النص بلخبطه بس فهمتها في النهايه
# شكرا سيد صنع الله ، ولكن ساقرا امري كان لي واللجنه والتلصص عن قريب
# شكرا سيد صنع الله ، ولكن ساقرا امري كان لي واللجنه والتلصص عن قريب
# بصراحه اعجبني جدا وقوف السيد البدينه علي قدميها
# بصراحه اعجبني جدا وقوف السيد البدينه علي قدميها
# جفت ضمايركم , ما هزكم هذا النداء
# جفت ضمايركم , ما هزكم هذا النداء
# حقا ان العقاد لاديب بعقل عالم نسال الله عزوجل ان يرحمه ويسكنه فسيح جناته
# حقا ان العقاد لاديب بعقل عالم نسال الله عزوجل ان يرحمه ويسكنه فسيح جناته
# بس حسيت ان الروايه ناقصه حاجه
# بس حسيت ان الروايه ناقشه حاجه
# معني كتاب بالنسبالي كبير مش اي كلام يتحط فيه
# معني لتاب بالنسبالي كبير مش اي كلام يتحط قيه
# فعلتنا ليست الجهل, وانما هي التجاهل
# فعلتنا ليصت الجهل, وانما هي التجاهل
# متحمسه جدا للفيلم
# متحمسه جدا للفيلم
# واقول كان المفروض وكدا
# واقول كان المفروض وكدا
# في انتظار المعجزه القادمه لشافاق :)
# في انتظار المعجزه القادمه لشافاق :)
# اما الاولي فشدتني لانها عن تخصصي و شغفي
# اما الاولي فشدتني لانهأ عن تخصصي و شغفي
# بل ان الديمقراطيه عليها ان توفر لكل مواطنيها الفرصه العادله و المتكافيه للصعود الي قمه المجتمع
# بل ان الديمقراطيه عليها ان توفر لكل مواطنيها الفرصه العادله و المتكافيه للصعود الي قمه المجتمع
# قريته حوالي 5 مرات ممتع لاقصي الحدود ومبدع لاقصي الحدود انصح اي حد بيبتدي في القرايه انه يقراه
# قريته حوالي 5 مرات ممتع لاقصي الحدود ومبدغ لاقصي الحدود انصح اي حد بيبتدي في القرابه انه يقراه
# نقدي/ساخر
# نقدي/ساخذ
# الفكره الاساسيه مهمه جدا وطريقه مناقشتها كانت رايعه
# الفكره الاساسيه مهمه جدا وطريقه مناقشتها كانت رايعه
# هل يتساوي الصالح والطالح
# هل يتساوي الصالح والطالح
# اما الذي لم يعجبني فقد كانت مبالغه في كثير من الامور
# اما الذي لم يعجبني فقد كانت مبالغه قي كثير من الامور
# اسطورتها انها لا تشيخ ابدا,,
# اسطورتها انها لا تشيخ ابدا,,
# عن الاستبداد والظلم
# عن الاستبداد والظلم
# وعمق ماا سااحر
# وعمق ماا سااحر
# مش قصدي
# مش قصدي
# دحام/دهام: سلطان و عبدالرحمن بن عبد العزيز ال سعود
# دحام/دهام: سلطان و عبدالرحمن بن عبد العزيز ال سعود
# مهما استطال البلاء واستبد الزمن
# مهما استطال البلاء وأستبد الزمن
# كنت ادرك انك تقحمينني بتفاصيلك رغبه منك باقتحام تفاصيلي
# كنت ادرك انك تقحمينني بتفاصيلك رغبه منك باقتحام تفاصيلي
# المتني العباره قدر ما المتني الروايه
# ىلمتني العباره قدر مإ المتني الروايه
# غير مقنع و الملحدين معظمهم ملحدين مش عشان الاسباب ديي
# غير مقنع و الملحدين معظمهم ملحدين مص عشان الاسباب ديي
# حرب 1948 و بدايه استيلاء اسراييل علي الاراضي بالقوه
# حذب 1948 و بدىيه استيلاء اسراييل علي إلاراضي بالقوه
# سمع اهل السوق بكاء الطفل الرضيع ومع هذا الصوت الصادر من غرينوي
# سمع اهل السوق بكاء الطفل الرضيع ومع هذا الصوت ىلصادر من غرينوي
# وحروب ندخلها
# وحرون ندخلها
# انا بتكسف جدا لما اقيم كتب
# انا بتكسف جدا لما اقيم كتب
# قصه الروايه وكاتبها المعروف بالنسبه لي
# قصه الروايه وكاتبها المعروف بالنسبه لي
# هل الانسان لهذا الحد له بعد واحد ومحرك وحيد
# هل الانسان لهذا الحد له بعد واحد ومحرك وحيد
# مواجهه المشكلات ( تذكر ايجابيات شريكك )
# مواجهه اكمشكلات ( تذكر ايجابيات شريكك )
# وحرايق غيطان القصب لتتشرب الارض ببقايا رمادالخصوبه, وادخنه المر والعطر
# وحرايق غيطان القصب لتتشرب الارص ببقايا زمادالخصوبه, وادخنه ءلمر والعطر
# وكل العيون
# وكل العيون
# ومن العدل ان تكون مثلهم تماما
# ومن العدل أن تكون مثلهم تماما
# استمر انت بجد كاتب رايع وبعد ما قريت طاري واثق ان لا شي مما سبق مش هتقل عنها
# استمر انت بجد كاتب رايع وبعد ما قريت طاري واثق ان لا شي مما سبق نش هتقل عنها
# رغم ان هذه العناوين لا تجذبني لكن مذ تصفحت المقدمه جذبتني الكلمات الاولي
# رغم ان هذه العناوين لا تجذبني لكن مذ تصفحت المقدمه جذبتني الكلمات الاولي
# كعاده دكتور مصطفي محمود كتاب ممتع , قيم , مفيد , شيق كل وسايل الامتاع الادبي
# كعىده دكتور مصطفي محمود كتاب ممتع , قيم , مفيد , شيق كل وشايل الامتاع الادبي
# ديوان بسيط قراته قبل سنتين فيه ما هو راياع وما هو عادي ،واكثر شيء اعجبني فيه :
# ديوان بسيط قراته قبل صنتين فيه ما هو راياع وما هو عادي ،واكثر شيء اعجبني فيه :
# الاحداث سريعه
# الاحداث سريعه
# بس وقت ما نكون مستعدين ليها هتلاقيها جتلك في اشاره تريح بالك
# بس وفت ما نلون مستعذين ليها هتلاقيها جتلك في اشاره تريح بالك
# وفي كل مرحله من مراحل العمر
# وفي كل مرحله من مراحل العمر
# اعشق الكلام عن اي شي
# اعشق الكلام عن اي شي
# قليله هي الجمل الي تصلح كاقتباسات ولكن اجزم انه ليس اخر الكتب التي اقراها لتامر ابراهيم
# قليله هي الجمل الي بصلح كاقتباسات ولكن اجزم انه ليس اخذ الكتب التي اقراها لتامر ابراهيم
# يخرج منا لينشق عنا ليعود مكرها بعد طوي الكتاب
# يخرج منا لينشق عنأ ليعود مكرها بعد طوي الكتاب
# جنون عظمه
# جنون عظنه
# و الحقيقه الواضحه هي : ان من يتخذ من كبريايه درعا ، لابد له من اصابه تجرحه وتهينه
# و الحقيقه الواضحه هي : ان من يتخذ من كبريايه درغا ، لابد له من اصابه تجرحة وتهينة
# لكن سردك للروايه ولا اروع
# لكن سردك للروايه ولا اروع
# كما و ادهشتني قدره الكاتبه علي وصف اكثر المشاعر دفيا بالنسبه لرجل
# كما و ادهشتني قدره الكاتبه علي وصف اكثر المشاعر دفيا بالنسبه لرجل
# ينفع فيلم اكشن كويس بس حبيت الفيل الازرق اكتر
# ينفع فيلم اكشن كويس بس حبيت الفيل الازرق اكتر
# متعدد الالوان
# متعدد الالوان
# عم ابراهيم بيفكرني بعمو تاني سمعت عنه حكايه مشابهه ^_^
# عم ابراهيم بيفكرني بغمو تأني سمعت عنه حكايه مشابهه ^_^
# ما هو وجه الابداع في جعل نجيب محفوظ
# ما هو وجه الابداع فب جعل نجيب محفوظ
# اجمل اقدارنا تلك التي تباغتنا دهشه وبهاء "
# اجمل اقدارنا تلك التي تباغتنا دهشه وبهاء "
# ان المطلوب من الحوار لا يشترط ان يكون توحيد الراي دايما
# ان المطلوب من الحوار لا يشترط ءن يكون توحيد الراي دايما
# هذا الكتاب اكبر من عقلي
# هذا الكتاب اكبر من عقلي
# وتعنون لفصول روايتها بالسنين
# وتعنون لفصول روايتها بالسنين
# لا ريب ان فرويد حللها تحليلا عميق
# كا ريب ان فرويد حللها تحليلا عميف
# واضايقت منهم في وقت تاني عشت معاها اليومين الي قريتها فيهم
# واضايقت منهم في وقت تاني عشت معاها اليومين الي قريتها فيهم
# الرجل نوراني ومحتسي لبلاغه القران علي مهل
# الرجل نوراني ومحتسي لبلاغه القران علي مهل
# لكني اكذبها
# لكني اكذبها
# الكتاب رثاء في مفقودها العزيز
# الكتاب رثاء في مفقودها العزيز
# يبدو قرننا هذا اكثر حرصا علي الاتقان
# يبدو قرننا هذا اكثر حرصا علي الاتقان
# حسيته بيتكلم عني للاسف
# حسبته بيتكلم غني للاسف
# 16) عيب الزمان
# 16) عيب الزمان
# ليس به شيء خاص، ولكنه مفيد للتذكير باهميه الوقت والمحافظه عليه
# ليس به شيء خاص، ولكنه مفيد للتذكير باةميه الوقت والمحافظه عليه
# كعادتها اجاثا تفاجيني باسلوبها
# كعادتها اجاثا تقاجيني باسلوبها
# *ان العذاب لا يتناقض مع الرحمه بل يكون احيانا هو عين الرحمه
# *ان العذاب لا يتناقض مع الرجمه بل يكون احيانا هو عين الرحمه
# روايه رايعه رغم الالم، فالالم حقيقي والموت حقيقي والحرب حقيقيه
# روايه رايعه رغم الالم، فالالم حقيقي والموت حقيقي والحرب حقيقيه
# في كل حكايه جوهره ،وكل جوهره تغني لها الشعر
# في لل حكايه جوهره ،وكل جوهره تغني لها الشعر
# و لا بالغاز المسيل للدموع
# و كا بالغاز المسيل للدموع
# ابيات تجمع بين الحكمه والبلاغه والادب والذوق الفريد
# ابيات تجمع بين الحكمه والبلاغه والادب والذوق الفريد
# راجع صفحات ???
# راحع صفحات ???
# كتاب بسيط و خفيف يحتوي علي خواطر
# كتاب بسيط و خفيف يحتوي علي خواطر
# كقصه فهو رايع بصراحه
# كقصه فهو رايع بصراحه
# انسان جميل مليي بالخيال وهذا اقل ما استطيع قوله عنه
# انسان جنيل مليي بالخيال وهذا اقل ما استطيع قوله عنه
# اعجبتني الخاتمه، لو انني في مكان فهد لبكيت
# اعجبتني الخاتمه، لو انني في مكان فهد لبكيت
# رحمك الله جعلت حبرك فخر لكل سعودي
# رحمل الله جعلت حبرك فخر لكل سعودي
# لا تليق ابدا باحمد خالد توفيق
# لا تليق ابدا باحمد خاكد توفيق
# كعاده النهايات الحزينه اللي الكاتب حاول يخلي فيها قصه الحب خالده
# كعاده النهايات الحزينه اللي اللاتب حاول يخلي قيها قصه الحب خالده
# و ايضا وجدته سوداوي في بعض الاوقات ولكن ابرر ذلك في "التغيير بالصدمه"
# و ايضا وجدته سوداوي في بعض الاوقات ولكن ابرر ذلك قي "التغيير بالصدمه"
# بل انها اساءت اليه اكثر
# بل انها اساءت اليه ءكثر
# ترددت كثيرا قبل التقييم
# ترددت كثيرا قبل التقييم
# - هل الشريعه ستتسبب في فتن عنصريه مع الاقليات في الدول الاسلاميه
# - هل الصريعه ستتسبب في فتن عنضريه مع الاقليات في الدول الاسلإميه
# الحب من وجهه نظر الميتافيزيقا كونه مجرد هرمونات
# الحب من وجهه نظر الميتافيزيقا كونه مجرذ هرمونات
# تشعر انك بصدد قراءه كتاب قوي ودسم
# تشعر انك بصدد قراءه كتأب قوي وذسم
# و فارس ايضا شخصيه واقعيه الي حد كبير
# و فارس ايضا شخصيه واقعيه الي حد كبير
# لكن بعد قراءه الروايه و اعجابي الشديد بشخصيه الشيخ حاتم الشناوي ، انا شايف انه ييجي منه و بشده
# لكن بعد قراءه الروايه و اعجابي الشديد بشخصيه الشيخ حاتم الشناوي ، انا شايف انه ييجي منه و بشده
# بعد الانتهاء:
# بعد الانتهاء:
# احسن دستور في تاريخ البشريه ، بس راح
# احسن دستور في تاريخ البشريه ، بس راح
# هوالتيه بلا شك ما رافقني خلال ابحاري ما بين دفتي هذا العمل
# هوالتيه بلا شك ما رافقني خلال ابحاري ما بين دفتي هذا العمل
# قصه سامي الحاج
# قضه صامي ءلحاج
# Sentence-level accuracy: 0.7850

# %%
def evaluate_autocorrect_model(clean_sentences, noisy_sentences, verbose=True):
    assert len(clean_sentences) == len(noisy_sentences), "Mismatched input lengths."
    
    sentence_correct = 0
    word_accuracies = []
    
    for clean, noisy in zip(clean_sentences, noisy_sentences):
        predicted = autocorrect(noisy)
        
        if predicted == clean:
            sentence_correct += 1
        
        clean_words = clean.split()
        predicted_words = predicted.split()
        correct_words = sum(1 for cw, pw in zip(clean_words, predicted_words) if cw == pw)
        word_accuracy = correct_words / max(len(clean_words), 1)
        word_accuracies.append(word_accuracy)

        print("🔸 Noisy:     ", noisy)
        print("🔁 Predicted:", predicted)
        print("✅ Target:   ", clean)
        if predicted == clean and noisy != clean: 
            print("Corrected a mistake!")
        if predicted == clean and noisy == clean: 
            print("Correct, but no mistake was found")
        print()

    total = len(clean_sentences)
    print(f"\n📏 Sentence-level accuracy: {sentence_correct}/{total} = {sentence_correct/total:.2%}")
    print(f"📊 Avg. word-level accuracy: {np.mean(word_accuracies):.2%}")

# %%
sentence1 = "أنا أجب المدرصة"
sentence2 = "أنا أشعر بالحوع"
sentence3 = "الحديقة حميلة جدًا"
sentence4 = "أدرس اللغة العزبية"
sentence5 = "أحب أتغلم البرمجة"
sentence6 = "السماء ززقاء صافية"
sentence7 = "مغالجة اللغات الطبيعية"
print(autocorrect(sentence1))
# Out:
# انا احب المدرسه

# %%
import tkinter as tk
def correct_sentence():
    input_text = entry.get()
    corrected = autocorrect(input_text)
    result_label.config(text=" التصحيح: " + corrected)

root = tk.Tk()
root.title("Arabic Sentence Autocorrector")
root.geometry("500x200")

label = tk.Label(root, text="أدخل الجملة العربية:", font=("Arial", 14))
label.pack(pady=10)

entry = tk.Entry(root, font=("Arial", 14), justify='right')
entry.pack(fill='x', padx=20)

button = tk.Button(root, text="تصحيح", font=("Arial", 12), command=correct_sentence)
button.pack(pady=10)

result_label = tk.Label(root, text="", font=("Arial", 14), fg="green", wraplength=480, justify='right')
result_label.pack(pady=10)

root.mainloop()
